# %% [markdown]
# # Tsdat Out-of-the-box tutorial
# In this self-explained notebook, we walk you through an example pipeline predefined in `example_pipeline` module.

# %% [markdown]
# # Prerequisite
# We assume that
# - the conda environment is correctly setup
# - required dependencies defined in `requirements-dev.txt` are installed.

# %% [markdown]
# # Working path configuration
# In the following sessiong, we configure the working path to project root path to make sure the path of yaml files in `config/` are correctly resolved.
# TODO: make relative path resolve more robust.

# %%
import os
from pathlib import Path

import warnings
warnings.filterwarnings('ignore')

# %%
# inspect current path and working path
try: # only assign once
    path_original: str
    if not path_original:
        path_original: str = os.getcwd()
except:
    path_original: str = os.getcwd()
print("current path: \n", path_original)
print("current working path: \n", os.getcwd())

# # command line fashion
# # in UNIX/MAC/LINUX
# ! pwd
# # in WINDOWS
# ! dir
# Out:
# current path:
#  /home/kefei/sandbox/ingest-template/pipelines/example_pipeline
# current working path:
#  /home/kefei/sandbox/ingest-template/pipelines/example_pipeline

# %%
# retrieve root path. (two layers above) i.e., <path_to_git_clone>/ingest-template/
root_path = Path(path_original).parent.parent.absolute()
print("root path: \n", root_path)

# change working path to ROOT_PATH
os.chdir(root_path)
# double-check
print("current path: \n", path_original)
print("(new) working path: \n", os.getcwd())
# Out:
# root path:
#  /home/kefei/sandbox/ingest-template
# current path:
#  /home/kefei/sandbox/ingest-template/pipelines/example_pipeline
# (new) working path:
#  /home/kefei/sandbox/ingest-template

# %% [markdown]
# ### Pipeline Steps
# - define configuration file path
# - define pipeline configuration
# - instantiate the pipeline
# - (optional) validate pipeline output

# %%
import xarray as xr
from pathlib import Path
from tsdat import PipelineConfig, assert_close

# %%
# define configuration file path
config_path = Path("pipelines/example_pipeline/config/pipeline.yaml")
print("config_path: \n", config_path)
print("absolute config_path: \n", config_path.absolute())
# Out:
# config_path:
#  pipelines/example_pipeline/config/pipeline.yaml
# absolute config_path:
#  /home/kefei/sandbox/ingest-template/pipelines/example_pipeline/config/pipeline.yaml

# %%
# define pipeline configuration
config = PipelineConfig.from_yaml(config_path)
config
# Out:
# PipelineConfig(classname='pipelines.example_pipeline.pipeline.ExamplePipeline', parameters={}, triggers=[re.compile('.*example_pipeline.*\\.csv')], retriever=RetrieverConfig(classname='tsdat.io.retrievers.DefaultRetriever', parameters={}, readers={re.compile('.*'): DataReaderConfig(classname='tsdat.io.readers.CSVReader', parameters={})}, data_vars={'wave_type': {'.*': {'name': 'WaveType'}}, 'num_zero_crossings': {'.*': {'name': 'ZCN'}}, 'mean_wave_height': {'.*': {'name': 'Havg'}}, 'mean_wave_period_ts': {'.*': {'name': 'Tavg'}}, 'mean_wave_period': {'.*': {'name': 'MeanPeriod'}}, 'mean_wave_direction': {'.*': {'name': 'MeanDirection'}}, 'mean_wave_spread': {'.*': {'name': 'MeanSpread'}}, 'max_wave_height': {'.*': {'name': 'Hmax'}}, 'max_wave_period': {'.*': {'name': 'Tmax'}}, 'significant_wave_height_ts': {'.*': {'name': 'Hsig'}}, 'significant_wave_period': {'.*': {'name': 'Tsig'}}, 'significant_10_wave_height': {'.*': {'name': 'H110'}}, 'significant_10_wave_period': {'.*': {'name': 'T110'}}, 'max_crest_period': {'.*': {'name': 'MaxCrest'}}, 'peak_wave_period': {'.*': {'name': 'PeakPeriod'}}, 'peak_wave_direction': {'.*': {'name': 'PeakDirection'}}, 'peak_wave_spread': {'.*': {'name': 'PeakSpread'}}, 'peak_wave_period_read': {'.*': {'name': 'TP5'}}, 'significant_wave_height': {'.*': {'name': 'HM0'}}, 'wave_energy_period': {'.*': {'name': 'Te'}}, 'wave_duration': {'.*': {'name': 'DurationMs'}}, 'F1': {'.*': {'name': 'F1'}}, 'F2': {'.*': {'name': 'F2'}}}, coords={'time': {'.*': {'name': 'DataTimeStamp', 'data_converters': [{'classname': 'tsdat.io.converters.StringToDatetime', 'format': '%Y-%m-%d %H:%M:%S', 'timezone': 'UTC'}]}}}), dataset=DatasetConfig(attrs=GlobalAttributes(title='Wave Measurements from Buoy #130 at Morro Bay, CA', description='Pacific Northwest National Laboratory (PNNL) manages this AXYS WindSentinelTM buoy (Buoy #130) on behalf of the U.S. Department of Energy (DOE) that collect a comprehensive set of meteorological and oceanographic (metocean) data to support resource characterization for wind energy offshore. The buoy collects in-situ sea surface temperature, salinity, ocean currents, and wave data as well as near-surface air temperature, humidity, and horizontal wind speed and direction.', code_url=None, conventions=None, doi=None, institution=None, references=None, location_id='morro', dataset_name='buoy_z06', qualifier='waves', temporal=None, data_level='a1', datastream='morro.buoy_z06-waves.a1', history='', code_version='0.1.0-post.23+7fe618a.dirty'), coords={'time': Coordinate(name='time', data=None, dtype='datetime64[s]', dims=['time'], attrs=VariableAttributes(units='Seconds since 1970-01-01 00:00:00', long_name=None, standard_name=None, comment=None, valid_range=None, fail_range=None, warn_range=None, valid_delta=None, fail_delta=None, warn_delta=None, fill_value=None))}, data_vars={'wave_type': Variable(name='wave_type', data=None, dtype='double', dims=['time'], attrs=VariableAttributes(units='1', long_name='Wave Type', standard_name=None, comment='User-programmable classification of different wave types. Wave types are not defined for this deployment', valid_range=None, fail_range=None, warn_range=None, valid_delta=None, fail_delta=None, warn_delta=None, fill_value=-9999.0)), 'num_zero_crossings': Variable(name='num_zero_crossings', data=None, dtype='int', dims=['time'], attrs=VariableAttributes(units='1', long_name='Number of Zero Crossings', standard_name=None, comment=None, valid_range=None, fail_range=None, warn_range=None, valid_delta=None, fail_delta=None, warn_delta=None, fill_value=-9999.0)), 'mean_wave_height': Variable(name='mean_wave_height', data=None, dtype='double', dims=['time'], attrs=VariableAttributes(units='m', long_name='Average Wave Height', standard_name=None, comment='Wave height, average calculated from timeseries', valid_range=[0.0, 10.0], fail_range=None, warn_range=None, valid_delta=None, fail_delta=None, warn_delta=None, fill_value=-9999.0)), 'mean_wave_period': Varia ...

# %%
# instantiate the pipeline
pipeline = config.instantiate_pipeline()

# %%
# (optional) validate pipeline output

input_file = "pipelines/example_pipeline/test/data/input/buoy.z06.00.20201201.000000.waves.csv"
expected_file = "pipelines/example_pipeline/test/data/expected/morro.buoy_z06-waves.a1.20201201.000000.nc"

dataset = pipeline.run([input_file])
expected: xr.Dataset = xr.open_dataset(expected_file)  # type: ignore

# assert_close(dataset, expected, check_fill_value=False, check_attrs=False)

# %%
# inspect input file
import pandas as pd
df_input = pd.read_csv(input_file)
df_input.head()
# Out:
#          DataTimeStamp  WaveType    ZCN  Havg   Tavg   Hmax  Tmax  MaxCrest  \
# 0  2020-12-01 00:00:00       0.0  173.0  1.45  6.199  3.940   NaN       NaN
# 1  2020-12-01 00:20:00       0.0  185.0  1.47  5.900  3.569   NaN       NaN
# 2  2020-12-01 00:40:00       0.0  171.0  1.57  6.099  3.440   NaN       NaN
# 3  2020-12-01 01:00:00       0.0  166.0  1.57  6.300  3.710   NaN       NaN
# 4  2020-12-01 01:20:00       0.0  165.0  1.61  6.199  3.359   NaN       NaN
#
#     Hsig   Tsig  ...  MeanSpread  PeakPeriod  PeakDirection  PeakSpread   TP5  \
# 0  2.289  8.800  ...        29.6        20.0            NaN         NaN  16.6
# 1  2.299  8.000  ...        30.1        18.2            NaN         NaN  14.8
# 2  2.390  8.899  ...        27.6        14.3            NaN         NaN  13.5
# 3  2.460  9.100  ...        29.1        18.2            NaN         NaN  18.1
# 4  2.470  9.100  ...        29.2        18.2            NaN         NaN  16.0
#
#      HM0  Te  DurationMs  F1  F2
# 0  2.589 NaN         NaN NaN NaN
# 1  2.589 NaN         NaN NaN NaN
# 2  2.640 NaN         NaN NaN NaN
# 3  2.750 NaN         NaN NaN NaN
# 4  2.779 NaN         NaN NaN NaN
#
# [5 rows x 24 columns]

# %%
# inspect pipeline output
dataset
# Out:
# <xarray.Dataset>
# Dimensions:                     (time: 72)
# Coordinates:
#   * time                        (time) datetime64[ns] 2020-12-01 ... 2020-12-...
# Data variables: (12/28)
#     wave_type                   (time) float64 ...
#     num_zero_crossings          (time) float64 ...
#     mean_wave_height            (time) float64 ...
#     max_wave_height             (time) float64 ...
#     max_wave_period             (time) float64 ...
#     max_crest_period            (time) float64 ...
#     ...                          ...
#     qc_mean_wave_spread         (time) int32 ...
#     qc_peak_wave_period         (time) int32 ...
#     qc_peak_wave_direction      (time) int32 ...
#     qc_peak_wave_spread         (time) int32 ...
#     qc_significant_wave_height  (time) int32 ...
#     qc_wave_energy_period       (time) int32 ...
# Attributes:
#     title:         Wave Measurements from Buoy #130 at Morro Bay, CA
#     description:   Pacific Northwest National Laboratory (PNNL) manages this ...
#     location_id:   morro
#     dataset_name:  buoy_z06
#     qualifier:     waves
#     data_level:    a1
#     datastream:    morro.buoy_z06-waves.a1
#     history:       Ran by kefei at 2022-04-28T11:07:48.647093
#     code_version:  0.1.0-post.23+7fe618a.dirty
